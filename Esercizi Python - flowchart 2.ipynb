# %% [markdown]
# # ESERCIZI SECONDA PARTE
#
# I flowchart sono stati creati con [flowgorithm](http://www.flowgorithm.altervista.org/HTML%20ITA/) con
# [MANUALE in italiano](http://www.flowgorithm.org/documentation/files/Flowgorithm%20manuale%20ITA%202.22.pdf)

# %% [markdown]
# # ESERCIZIO 1
# Dato il seguente flow chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# scrivi la sua traduzione in Python sapendo che per visualizzare un numero preceduto da una stringa la sintassi in Python è:
#
# ```
# print("il valore di numero è " + str(numero))
# ```
# dove la funzione str() trasforma un numero in una stringa.
# Con l'operatore '+' è possibile concatenare 2, 3, 4, ... n stringhe differenti.

# %% [markdown]
# # ESERCIZIO 2
# Dato il seguente flow chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# scrivi la sua traduzione in Python

# %% [markdown]
# # ESERCIZIO 3
#
# Dato il seguente flow chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# scrivi la sua traduzione in Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # FINE SECONDA PARTE
